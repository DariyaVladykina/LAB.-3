# %%
Наименование проекта: Морфологический анализатор естественного языка с функцией машинного перевода
Цель проекта: Создать программу на базе национального корпуса русского языка, осуществляющую морфологический анализ текста.
Задачи:
1. Подготовить и разделить текст на токены
2. С помощью библиотеки pymorphy2 исследовать фрагмент текста на наличие определенных граммем
3. С помощью машинного переводчика перевести нужные граммемы и добавить их в память перевода
Функциональные требования: 
- токенизация текста
- использование данных из национального копуса русского языка
- осуществление машинного перевода 
- добавление данных в память переводов
Входные данные: токенезированный текст
Выходное воздействие: анализ данных и перевод

# %%
from pymorphy2 import MorphAnalyzer
from nltk.tokenize import WordPunctTokenizer
ma = MorphAnalyzer()
wpt = WordPunctTokenizer()
# пример объектов библиотек
